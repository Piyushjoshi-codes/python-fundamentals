# %% [markdown]
# This is the beginning of the era of the code where humanity reaches it's ultimatum and growth feels exponential. Coding has become a part of our life. Everywhere there is digital technology, there is a code, there is an information and a new start of life, a new era...
# Starting with binary numbers (0, 1), then assembly languages and now the programming langauges, where the computer(an electronic device used for several operations, services, formation, destruction, etc..)
# communicates with us with no language barrier (knowing it only knows 0 and 1) and with increasing efficiency...
# We present you, the code of itself, the first ever code to be used for it's explicit simplicity..

# %%
print("Hello World")

# %% [markdown]
# It's origin came from 1972, when a computer scientist named 'Brian Kernighan' first invented the C language and to check the handling of code <he first printed the text "HelloWorld">.
# It is said that easier it is to write the code for hello world, easier is that programming langauge to work with.
